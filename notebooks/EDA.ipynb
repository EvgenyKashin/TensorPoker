# %%
from pypokerengine.players import BasePokerPlayer
from pypokerengine.utils.card_utils import gen_cards, estimate_hole_card_win_rate, _montecarlo_simulation
from pypokerengine.api.game import setup_config, start_poker

import random as rand

# %% [markdown]
# ## CallPlayer

# %%
class CallPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"

    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]
        call_action_info = valid_actions[1]
        action, amount = call_action_info["action"], call_action_info["amount"]
        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %% [markdown]
# ## FoldPlayer

# %%
class FoldPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"
    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]
        call_action_info = valid_actions[0]
        action, amount = call_action_info["action"], call_action_info["amount"]
        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %% [markdown]
# ## HeuristicPlayer

# %%
class HeuristicPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"
    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]
        call_action_info = valid_actions[1]
        fold_action_info = valid_actions[0]

        community_card = round_state['community_card']
        win_rate = estimate_hole_card_win_rate(nb_simulation=150, nb_player=self.nb_player,
                                               hole_card=gen_cards(hole_card),
                                               community_card=gen_cards(community_card))
        if win_rate > 1 / float(self.nb_player) + 0.1:
            action, amount = call_action_info["action"], call_action_info["amount"]
        else:
            action, amount = fold_action_info["action"], fold_action_info["amount"]
        return action, amount

    def receive_game_start_message(self, game_info):
        self.nb_player = game_info['player_num']

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %% [markdown]
# ## RandomPlayer

# %%
class RandomPlayer(BasePokerPlayer):
    def __init__(self):
        self.fold_ratio, self.call_ratio, raise_ratio = 1.0/5, 3.0/5, 1.0/5

    def set_action_ratio(self, fold_ratio, call_ratio, raise_ratio):
        ratio = [fold_ratio, call_ratio, raise_ratio]
        scaled_ratio = [ 1.0 * num / sum(ratio) for num in ratio]
        self.fold_ratio, self.call_ratio, self.raise_ratio = scaled_ratio

    def declare_action(self, valid_actions, hole_card, round_state):
        choice = self.__choice_action(valid_actions)
        action = choice["action"]
        amount = choice["amount"]
        if action == "raise":
            amount = rand.randrange(amount["min"], max(amount["min"], amount["max"]) + 1)
        return action, amount

    def __choice_action(self, valid_actions):
        r = rand.random()
        if r <= self.fold_ratio:
            return valid_actions[0]
        elif r <= self.call_ratio:
            return valid_actions[1]
        else:
            return valid_actions[2]


    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, new_action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %% [markdown]
# ## Simulations

# %%
config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
config.register_player(name="CallPlayer1", algorithm=CallPlayer())
config.register_player(name="CallPlayer2", algorithm=CallPlayer())
config.register_player(name="CallPlayer3", algorithm=CallPlayer())

config.register_player(name="FoldPlayer1", algorithm=FoldPlayer())
config.register_player(name="FoldPlayer2", algorithm=FoldPlayer())

config.register_player(name="HeuristicPlayer1", algorithm=HeuristicPlayer())
config.register_player(name="HeuristicPlayer2", algorithm=HeuristicPlayer())

config.register_player(name="RandomPlayer1", algorithm=RandomPlayer())
config.register_player(name="RandomPlayer2", algorithm=RandomPlayer())

game_result = start_poker(config, verbose=1)
# Out:
# Started the round 1
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer1" declared "fold:0"
# "RandomPlayer2" declared "raise:197"
# "CallPlayer1" declared "call:197"
# "CallPlayer2" declared "call:197"
# "CallPlayer3" declared "call:197"
# Street "flop" started. (community card = ['D3', 'H2', 'HJ'])
# "CallPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# "RandomPlayer2" declared "fold:0"
# "CallPlayer1" declared "call:0"
# Street "turn" started. (community card = ['D3', 'H2', 'HJ', 'D9'])
# "CallPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# "CallPlayer1" declared "call:0"
# Street "river" started. (community card = ['D3', 'H2', 'HJ', 'D9', 'CQ'])
# "CallPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# "CallPlayer1" declared "call:0"
# "['CallPlayer3']" won the round 1 (stack = {'CallPlayer1': 1303, 'CallPlayer2': 1303, 'CallPlayer3': 2091, 'FoldPlayer1': 1500, 'FoldPlayer2': 1500, 'HeuristicPlayer1': 1500, 'HeuristicPlayer2': 1500, 'RandomPlayer1': 1500, 'RandomPlayer2': 1303})
# Started the round 2
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer1" declared "fold:0"
# "RandomPlayer2" declared "fold:0"
# "CallPlayer1" declared "call:30"
# "CallPlayer2" declared "call:30"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# Street "flop" started. (community card = ['H8', 'D9', 'S6'])
# "CallPlayer3" declared "call:0"
# "CallPlayer1" declared "call:0"
# "CallPlayer2" declared "call:0"
# Street "turn" started. (community card = ['H8', 'D9', 'S6', 'HT'])
# "CallPlayer3" declared "call:0"
# "CallPlayer1" declared "call:0"
# "CallPlayer2" declared "call:0"
# Street "river" started. (community card = ['H8', 'D9', 'S6', 'HT', 'D7'])
# "CallPlayer3" declared "call:0"
# "CallPlayer1" declared "call:0"
# "CallPlayer2" declared "call:0"
# "['CallPlayer3']" won the round 2 (stack = {'CallPlayer1': 1273, 'CallPlayer2': 1273, 'CallPlayer3': 2181, 'FoldPlayer1': 1470, 'FoldPlayer2': 1500, 'HeuristicPlayer1': 1500, 'HeuristicPlayer2': 1500, 'RandomPlayer1': 1500, 'RandomPlayer2': 1303})
# Started the round 3
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer1" declared "call:30"
# "RandomPlayer2" declared "raise:404"
# "CallPlayer1" declared "call:404"
# "CallPlayer2" declared "call:404"
# "CallPlayer3" declared "call:404"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "RandomPlayer1" declared "call:404"
# Street "flop" started. (community card = ['C8', 'H5', 'S6'])
# "RandomPlayer1" declared "call:0"
# "RandomPlayer2" declared "raise:342"
# "CallPlayer1" declared "call:342"
# "CallPlayer2" declared "call:342"
# "CallPlayer3" declared "call:342"
# "RandomPlayer1" declared "raise:912"
# "RandomPlayer2" declared "raise:-1"
# "CallPlayer1" declared "call:912"
# "CallPlayer2" declared "call:912"
# "CallPlayer3" declared "call:912"
# Street "turn" started. (community card = ['C8', 'H5', 'S6', 'C2'])
# "RandomPlayer1" declared "fold:0"
# Street "river" started. (community card = ['C8', 'H5', 'S6', 'C2', 'H7'])
# "['CallPlayer3']" won the round 3 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 6834, 'FoldPlayer1': 1455, 'FoldPlayer2': 1470, 'HeuristicPlayer1': 1500, 'HeuristicPlayer2': 1500, 'RandomPlayer1': 184, 'RandomPlayer2': 557})
# Started the round 4
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer1" declared "raise:168"
# "RandomPlayer2" declared "call:168"
# "CallPlayer3" declared "call:168"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# Street "flop" started. (community card = ['C3', 'CJ', 'C4'])
# "RandomPlayer1" declared "call:0"
# "RandomPlayer2" declared "raise:216"
# "CallPlayer3" declared "call:216"
# "RandomPlayer1" declared "raise:-1"
# Street "turn" started. (community card = ['C3', 'CJ', 'C4', 'DQ'])
# "RandomPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# Street "river" started. (community card = ['C3', 'CJ', 'C4', 'DQ', 'S8'])
# "RandomPlayer2" declared "raise:84"
# "CallPlayer3" declared "call:84"
# "['CallPlayer3']" won the round 4 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7515, 'FoldPlayer1': 1455, 'FoldPlayer2': 1455, 'HeuristicPlayer1': 1470, 'HeuristicPlayer2': 1500, 'RandomPlayer1': 16, 'RandomPlayer2': 89})
# Started the round 5
# Street "preflop" started. (community card = [])
# "RandomPlayer1" declared "raise:-1"
# "RandomPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 5 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7560, 'FoldPlayer1': 1455, 'FoldPlayer2': 1455, 'HeuristicPlayer1': 1455, 'HeuristicPlayer2': 1470, 'RandomPlayer1': 16, 'RandomPlayer2': 89})
# Started the round 6
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer2" declared "raise:60"
# "CallPlayer3" declared "call:60"
# Street "flop" started. (community card = ['SQ', 'H8', 'C7'])
# "RandomPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# Street "turn" started. (community card = ['SQ', 'H8', 'C7', 'CA'])
# "RandomPlayer2" declared "raise:-1"
# "['CallPlayer3']" won the round 6 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7635, 'FoldPlayer1': 1455, 'FoldPlayer2': 1455, 'HeuristicPlayer1': 1455, 'HeuristicPlayer2': 1455, 'RandomPlayer1': 0, 'RandomPlayer2': 29})
# Started the round 7
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer2" declared "call:30"
# Street "flop" started. (community card = ['HQ', 'HT', 'S9'])
# Street "turn" started. (community card = ['HQ', 'HT', 'S9', 'S5'])
# Street "river" started. (community card = ['HQ', 'HT', 'S9', 'S5', 'SA'])
# "['RandomPlayer2']" won the round 7 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7606, 'FoldPlayer1': 1455, 'FoldPlayer2': 1455, 'HeuristicPlayer1': 1455, 'HeuristicPlayer2': 1455, 'RandomPlayer1': 0, 'RandomPlayer2': 58})
# Started the round 8
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer2" declared "call:30"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# Street "flop" started. (community card = ['H3', 'S7', 'DJ'])
# "CallPlayer3" declared "call:0"
# "RandomPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 8 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7666, 'FoldPlayer1': 1425, 'FoldPlayer2': 1455, 'HeuristicPlayer1': 1455, 'HeuristicPlayer2': 1455, 'RandomPlayer1': 0, 'RandomPlayer2': 28})
# Started the round 9
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "call:30"
# "RandomPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# Street "flop" started. (community card = ['HJ', 'S6', 'DT'])
# "HeuristicPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# Street "turn" started. (community card = ['HJ', 'S6', 'DT', 'D6'])
# "HeuristicPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# Street "river" started. (community card = ['HJ', 'S6', 'DT', 'D6', 'C5'])
# "HeuristicPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# "['HeuristicPlayer2']" won the round 9 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7636, 'FoldPlayer1': 1410, 'FoldPlayer2': 1425, 'HeuristicPlayer1': 1455, 'HeuristicPlayer2': 1530, 'RandomPlayer1': 0, 'RandomPlayer2': 28})
# Started the round 10
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer2" declared "raise:-1"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 10 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7681, 'FoldPlayer1': 1410, 'FoldPlayer2': 1410, 'HeuristicPlayer1': 1425, 'HeuristicPlayer2': 1530, 'RandomPlayer1': 0, 'RandomPlayer2': 28})
# Started the round 11
# Street "preflop" started. (community card = [])
# "RandomPlayer2" declared "call:30"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# Street "flop" started. (community card = ['HQ', 'SA', 'S9'])
# Street "turn" started. (community card = ['HQ', 'SA', 'S9', 'CQ'])
# Street "river" started. (community card = ['HQ', 'SA', 'S9', 'CQ', 'D3'])
# "['RandomPlayer2']" won the round 11 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7655, 'FoldPlayer1': 1410, 'FoldPlayer2': 1410, 'HeuristicPlayer1': 1410, 'HeuristicPlayer2': 1500, 'RandomPlayer1': 0, 'RandomPlayer2': 99})
# Started the round 12
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "RandomPlayer2" declared "raise:65"
# "CallPlayer3" declared "call:65"
# Street "flop" started. (community card = ['C5', 'DA', 'DK'])
# "RandomPlayer2" declared "raise:30"
# "CallPlayer3" declared "call:30"
# Street "turn" started. (community card = ['C5', 'DA', 'DK', 'D2'])
# "RandomPlayer2" declared "raise:-1"
# "['CallPlayer3']" won the round 12 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7765, 'FoldPlayer1': 1410, 'FoldPlayer2': 1410, 'HeuristicPlayer1': 1410, 'HeuristicPlayer2': 1485, 'RandomPlayer1': 0, 'RandomPlayer2': 4})
# Started the round 13
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 13 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7795, 'FoldPlayer1': 1380, 'FoldPlayer2': 1410, 'HeuristicPlayer1': 1410, 'HeuristicPlayer2': 1485, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 14
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 14 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7840, 'FoldPlayer1': 1365, 'FoldPlayer2': 1380, 'HeuristicPlayer1': 1410, 'HeuristicPlayer2': 1485, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 15
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 15 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7885, 'FoldPlayer1': 1365, 'FoldPlayer2': 1365, 'HeuristicPlayer1': 1380, 'HeuristicPlayer2': 1485, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 16
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 16 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7930, 'FoldPlayer1': 1365, 'FoldPlayer2': 1365, 'HeuristicPlayer1': 1365, 'HeuristicPlayer2': 1455, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 17
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 17 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7945, 'FoldPlayer1': 1365, 'FoldPlayer2': 1365, 'HeuristicPlayer1': 1365, 'HeuristicPlayer2': 1440, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 18
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 18 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 7975, 'FoldPlayer1': 1335, 'FoldPlayer2': 1365, 'HeuristicPlayer1': 1365, 'HeuristicPlayer2': 1440, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 19
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "call:30"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# Street "flop" started. (community card = ['H5', 'S5', 'C4'])
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 19 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8050, 'FoldPlayer1': 1320, 'FoldPlayer2': 1335, 'HeuristicPlayer1': 1335, 'HeuristicPlayer2': 1440, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 20
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 20 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8095, 'FoldPlayer1': 1320, 'FoldPlayer2': 1320, 'HeuristicPlayer1': 1305, 'HeuristicPlayer2': 1440, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 21
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 21 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8140, 'FoldPlayer1': 1320, 'FoldPlayer2': 1320, 'HeuristicPlayer1': 1290, 'HeuristicPlayer2': 1410, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 22
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 22 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8155, 'FoldPlayer1': 1320, 'FoldPlayer2': 1320, 'HeuristicPlayer1': 1290, 'HeuristicPlayer2': 1395, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 23
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 23 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8185, 'FoldPlayer1': 1290, 'FoldPlayer2': 1320, 'HeuristicPlayer1': 1290, 'HeuristicPlayer2': 1395, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 24
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 24 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8230, 'FoldPlayer1': 1275, 'FoldPlayer2': 1290, 'HeuristicPlayer1': 1290, 'HeuristicPlayer2': 1395, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 25
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 25 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8275, 'FoldPlayer1': 1275, 'FoldPlayer2': 1275, 'HeuristicPlayer1': 1260, 'HeuristicPlayer2': 1395, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 26
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 26 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8320, 'FoldPlayer1': 1275, 'FoldPlayer2': 1275, 'HeuristicPlayer1': 1245, 'HeuristicPlayer2': 1365, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 27
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 27 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8335, 'FoldPlayer1': 1275, 'FoldPlayer2': 1275, 'HeuristicPlayer1': 1245, 'HeuristicPlayer2': 1350, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 28
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 28 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8365, 'FoldPlayer1': 1245, 'FoldPlayer2': 1275, 'HeuristicPlayer1': 1245, 'HeuristicPlayer2': 1350, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 29
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 29 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8410, 'FoldPlayer1': 1230, 'FoldPlayer2': 1245, 'HeuristicPlayer1': 1245, 'HeuristicPlayer2': 1350, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 30
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 30 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8455, 'FoldPlayer1': 1230, 'FoldPlayer2': 1230, 'HeuristicPlayer1': 1215, 'HeuristicPlayer2': 1350, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 31
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 31 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8500, 'FoldPlayer1': 1230, 'FoldPlayer2': 1230, 'HeuristicPlayer1': 1200, 'HeuristicPlayer2': 1320, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 32
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 32 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8515, 'FoldPlayer1': 1230, 'FoldPlayer2': 1230, 'HeuristicPlayer1': 1200, 'HeuristicPlayer2': 1305, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 33
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "call:30"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# Street "flop" started. (community card = ['HK', 'HJ', 'S3'])
# "CallPlayer3" declared "call:0"
# "HeuristicPlayer2" declared "call:0"
# Street "turn" started. (community card = ['HK', 'HJ', 'S3', 'D7'])
# "CallPlayer3" declared "call:0"
# "HeuristicPlayer2" declared "call:0"
# Street "river" started. (community card = ['HK', 'HJ', 'S3', 'D7', 'CA'])
# "CallPlayer3" declared "call:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 33 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8575, 'FoldPlayer1': 1200, 'FoldPlayer2': 1230, 'HeuristicPlayer1': 1200, 'HeuristicPlayer2': 1275, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 34
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 34 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8620, 'FoldPlayer1': 1185, 'FoldPlayer2': 1200, 'HeuristicPlayer1': 1200, 'HeuristicPlayer2': 1275, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 35
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 35 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8665, 'FoldPlayer1': 1185, 'FoldPlayer2': 1185, 'HeuristicPlayer1': 1170, 'HeuristicPlayer2': 1275, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 36
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 36 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8710, 'FoldPlayer1': 1185, 'FoldPlayer2': 1185, 'HeuristicPlayer1': 1155, 'HeuristicPlayer2': 1245, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 37
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 37 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8725, 'FoldPlayer1': 1185, 'FoldPlayer2': 1185, 'HeuristicPlayer1': 1155, 'HeuristicPlayer2': 1230, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 38
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 38 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8755, 'FoldPlayer1': 1155, 'FoldPlayer2': 1185, 'HeuristicPlayer1': 1155, 'HeuristicPlayer2': 1230, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 39
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 39 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8800, 'FoldPlayer1': 1140, 'FoldPlayer2': 1155, 'HeuristicPlayer1': 1155, 'HeuristicPlayer2': 1230, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 40
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 40 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8845, 'FoldPlayer1': 1140, 'FoldPlayer2': 1140, 'HeuristicPlayer1': 1125, 'HeuristicPlayer2': 1230, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 41
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 41 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8890, 'FoldPlayer1': 1140, 'FoldPlayer2': 1140, 'HeuristicPlayer1': 1110, 'HeuristicPlayer2': 1200, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 42
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 42 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8905, 'FoldPlayer1': 1140, 'FoldPlayer2': 1140, 'HeuristicPlayer1': 1110, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 43
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 43 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8935, 'FoldPlayer1': 1110, 'FoldPlayer2': 1140, 'HeuristicPlayer1': 1110, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 44
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 44 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 8980, 'FoldPlayer1': 1095, 'FoldPlayer2': 1110, 'HeuristicPlayer1': 1110, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 45
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 45 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 9025, 'FoldPlayer1': 1095, 'FoldPlayer2': 1095, 'HeuristicPlayer1': 1080, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 46
# Street "preflop" started. (community card = [])
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "['CallPlayer3']" won the round 46 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 9070, 'FoldPlayer1': 1095, 'FoldPlayer2': 1095, 'HeuristicPlayer1': 1065, 'HeuristicPlayer2': 1155, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 47
# Street "preflop" started. (community card = [])
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "call:30"
# "CallPlayer3" declared "call:30"
# Street "flop" started. (community card = ['CJ', 'H2', 'HJ'])
# "HeuristicPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# Street "turn" started. (community card = ['CJ', 'H2', 'HJ', 'D6'])
# "HeuristicPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# Street "river" started. (community card = ['CJ', 'H2', 'HJ', 'D6', 'ST'])
# "HeuristicPlayer2" declared "call:0"
# "CallPlayer3" declared "call:0"
# "['HeuristicPlayer2']" won the round 47 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 9040, 'FoldPlayer1': 1095, 'FoldPlayer2': 1095, 'HeuristicPlayer1': 1065, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 48
# Street "preflop" started. (community card = [])
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 48 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 9070, 'FoldPlayer1': 1065, 'FoldPlayer2': 1095, 'HeuristicPlayer1': 1065, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 49
# Street "preflop" started. (community card = [])
# "HeuristicPlayer1" declared "call:30"
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# Street "flop" started. (community card = ['HA', 'CJ', 'HJ'])
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 49 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 9145, 'FoldPlayer1': 1050, 'FoldPlayer2': 1065, 'HeuristicPlayer1': 1035, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Started the round 50
# Street "preflop" started. (community card = [])
# "HeuristicPlayer2" declared "fold:0"
# "CallPlayer3" declared "call:30"
# "FoldPlayer1" declared "fold:0"
# "FoldPlayer2" declared "fold:0"
# "HeuristicPlayer1" declared "fold:0"
# "['CallPlayer3']" won the round 50 (stack = {'CallPlayer1': 0, 'CallPlayer2': 0, 'CallPlayer3': 9190, 'FoldPlayer1': 1050, 'FoldPlayer2': 1050, 'HeuristicPlayer1': 1005, 'HeuristicPlayer2': 1185, 'RandomPlayer1': 0, 'RandomPlayer2': 0})
# Exception ignored in: <bound method GameSummarizer.__del__ of <pypokerengine.engine.dealer.GameSummarizer object at 0x7fa2a4bbcd68>>
# Traceback (most recent call last):
#   File "/home/digitman/python_projects/holdem-challenge/pypokerengine/engine/dealer.py", line 297, in __del__
#     self.summary_file.close()
# AttributeError: 'NoneType' object has no attribute 'close'

# %%
game_result
# Out:
# {'players': [{'name': 'CallPlayer1',
#    'stack': 0,
#    'state': 'participating',
#    'uuid': 'ewjmtzxsvzaqoqjfdunnkd'},
#   {'name': 'CallPlayer2',
#    'stack': 0,
#    'state': 'participating',
#    'uuid': 'cdzzbheqgresbuizrtnkhc'},
#   {'name': 'CallPlayer3',
#    'stack': 9190,
#    'state': 'participating',
#    'uuid': 'cmysgwkeldcucqasmivslp'},
#   {'name': 'FoldPlayer1',
#    'stack': 1050,
#    'state': 'participating',
#    'uuid': 'jgiielmhfluqmlghfitqik'},
#   {'name': 'FoldPlayer2',
#    'stack': 1050,
#    'state': 'participating',
#    'uuid': 'lmtpinxazfpvfworesntyc'},
#   {'name': 'HeuristicPlayer1',
#    'stack': 1005,
#    'state': 'participating',
#    'uuid': 'hhuwqpkxmovyixrxyimzxi'},
#   {'name': 'HeuristicPlayer2',
#    'stack': 1185,
#    'state': 'participating',
#    'uuid': 'zwotaigzyftzaixoexgkrb'},
#   {'name': 'RandomPlayer1',
#    'stack': 0,
#    'state': 'participating',
#    'uuid': 'alrxzpdkcccefosvgbscov'},
#   {'name': 'RandomPlayer2',
#    'stack': 0,
#    'state': 'participating',
#    'uuid': 'huwzikeijzuexjwfweqfnx'}],
#  'rule': {'ante': 0,
#   'blind_structure': {},
#   'initial_stack': 1500,
#   'max_round': 50,
#   'small_blind_amount': 15}}

# %% [markdown]
# ## Human player from console

# %%
import pypokerengine.utils.visualize_utils as U
from pypokerengine.players import BasePokerPlayer

class ConsolePlayer(BasePokerPlayer):
    def __init__(self, input_receiver=None):
        self.input_receiver = input_receiver if input_receiver else self.__gen_raw_input_wrapper()

    def declare_action(self, valid_actions, hole_card, round_state):
        print(U.visualize_declare_action(valid_actions, hole_card, round_state, self.uuid))
        action, amount = self.__receive_action_from_console(valid_actions)
        return action, amount

    def receive_game_start_message(self, game_info):
        print(U.visualize_game_start(game_info, self.uuid))
        self.__wait_until_input()

    def receive_round_start_message(self, round_count, hole_card, seats):
        print(U.visualize_round_start(round_count, hole_card, seats, self.uuid))
        self.__wait_until_input()

    def receive_street_start_message(self, street, round_state):
        print(U.visualize_street_start(street, round_state, self.uuid))
        self.__wait_until_input()

    def receive_game_update_message(self, new_action, round_state):
        print(U.visualize_game_update(new_action, round_state, self.uuid))
        self.__wait_until_input()

    def receive_round_result_message(self, winners, hand_info, round_state):
        print(U.visualize_round_result(winners, hand_info, round_state, self.uuid))
        self.__wait_until_input()

    def __wait_until_input(self):
        input("Enter some key to continue ...")

    def __gen_raw_input_wrapper(self):
        return lambda msg: input(msg)

    def __receive_action_from_console(self, valid_actions):
        flg = self.input_receiver('Enter f(fold), c(call), r(raise).\n >> ')
        if flg in self.__gen_valid_flg(valid_actions):
            if flg == 'f':
                return valid_actions[0]['action'], valid_actions[0]['amount']
            elif flg == 'c':
                return valid_actions[1]['action'], valid_actions[1]['amount']
            elif flg == 'r':
                valid_amounts = valid_actions[2]['amount']
                raise_amount = self.__receive_raise_amount_from_console(valid_amounts['min'], valid_amounts['max'])
                return valid_actions[2]['action'], raise_amount
        else:
            return self.__receive_action_from_console(valid_actions)

    def __gen_valid_flg(self, valid_actions):
        flgs = ['f', 'c']
        is_raise_possible = valid_actions[2]['amount']['min'] != -1
        if is_raise_possible:
            flgs.append('r')
        return flgs

    def __receive_raise_amount_from_console(self, min_amount, max_amount):
        raw_amount = self.input_receiver("valid raise range = [%d, %d]" % (min_amount, max_amount))
        try:
            amount = int(raw_amount)
            if min_amount <= amount and amount <= max_amount:
                return amount
            else:
                print("Invalid raise amount %d. Try again.")
                return self.__receive_raise_amount_from_console(min_amount, max_amount)
        except:
            print("Invalid input received. Try again.")
            return self.__receive_raise_amount_from_console(min_amount, max_amount)

# %%
config = setup_config(max_round=1, initial_stack=1500, small_blind_amount=15, summary_file='/dev/null')
config.register_player(name="HeuristicPlayer", algorithm=HeuristicPlayer())
config.register_player(name="ConsolePlayer", algorithm=ConsolePlayer())
game_result = start_poker(config, verbose=0)
# Out:
# -- Game start (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- rule --
#   - 2 players game
#   - 1 round
#   - start stack = 1500
#   -        ante = 0
#   - small blind = 15
# ======================================================================
# Enter some key to continue ...
# -- Round 1 start (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- hole card --
#   - ['SK', 'D9']
# -- players information --
#   - 0 : HeuristicPlayer (mrfdhwthmzmhsjwgobeymq) => state : participating, stack : 1470
#   - 1 : ConsolePlayer (qdpltubuojkdupqivqnfgc) => state : participating, stack : 1485
# ======================================================================
# Enter some key to continue ...
# -- New street start (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- street --
#   - preflop
# ======================================================================
# Enter some key to continue ...
# -- Declare your action (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 30
#   - raise: [45, 1500]
# -- hole card --
#   - ['SK', 'D9']
# -- round state --
#   - dealer btn : HeuristicPlayer
#   - street : preflop
#   - community card : []
#   - pot : main = 45, side = []
#   - players information
#     - 0 : HeuristicPlayer (mrfdhwthmzmhsjwgobeymq) => state : participating, stack : 1470 <= BB
#     - 1 : ConsolePlayer (qdpltubuojkdupqivqnfgc) => state : participating, stack : 1485 <= SB, CURRENT
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'amount': 15, 'add_amount': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
#       - {'action': 'BIGBLIND', 'amount': 30, 'add_amount': 15, 'player': 'HeuristicPlayer (uuid=mrfdhwthmzmhsjwgobeymq)'}
# ======================================================================
# Enter f(fold), c(call), r(raise).
#  >>
# Enter f(fold), c(call), r(raise).
#  >> c
# -- Game update (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- new action --
#   - ConsolePlayer (qdpltubuojkdupqivqnfgc) declared call: 30
# -- round state --
#   - dealer btn : HeuristicPlayer
#   - street : preflop
#   - community card : []
#   - pot : main = 60, side = []
#   - players information
#     - 0 : HeuristicPlayer (mrfdhwthmzmhsjwgobeymq) => state : participating, stack : 1470 <= BB
#     - 1 : ConsolePlayer (qdpltubuojkdupqivqnfgc) => state : participating, stack : 1470 <= SB, CURRENT
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'amount': 15, 'add_amount': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
#       - {'action': 'BIGBLIND', 'amount': 30, 'add_amount': 15, 'player': 'HeuristicPlayer (uuid=mrfdhwthmzmhsjwgobeymq)'}
#       - {'action': 'CALL', 'amount': 30, 'paid': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
# ======================================================================
# Enter some key to continue ...
# -- Game update (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- new action --
#   - HeuristicPlayer (mrfdhwthmzmhsjwgobeymq) declared fold: 0
# -- round state --
#   - dealer btn : HeuristicPlayer
#   - street : preflop
#   - community card : []
#   - pot : main = 60, side = []
#   - players information
#     - 0 : HeuristicPlayer (mrfdhwthmzmhsjwgobeymq) => state : folded, stack : 1470 <= BB, CURRENT
#     - 1 : ConsolePlayer (qdpltubuojkdupqivqnfgc) => state : participating, stack : 1470 <= SB
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'amount': 15, 'add_amount': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
#       - {'action': 'BIGBLIND', 'amount': 30, 'add_amount': 15, 'player': 'HeuristicPlayer (uuid=mrfdhwthmzmhsjwgobeymq)'}
#       - {'action': 'CALL', 'amount': 30, 'paid': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
#       - {'action': 'FOLD', 'player': 'HeuristicPlayer (uuid=mrfdhwthmzmhsjwgobeymq)'}
# ======================================================================
# Enter some key to continue ...
# -- Round result (UUID = qdpltubuojkdupqivqnfgc) --
# ======================================================================
# -- winners --
#   - ConsolePlayer (qdpltubuojkdupqivqnfgc) => state : participating, stack : 1530
# -- round state --
#   - dealer btn : HeuristicPlayer
#   - street : showdown
#   - community card : ['S2', 'HT', 'SJ', 'D4', 'H3']
#   - pot : main = 60, side = []
#   - players information
#     - 0 : HeuristicPlayer (mrfdhwthmzmhsjwgobeymq) => state : folded, stack : 1470 <= BB
#     - 1 : ConsolePlayer (qdpltubuojkdupqivqnfgc) => state : participating, stack : 1530 <= SB, CURRENT
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'amount': 15, 'add_amount': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
#       - {'action': 'BIGBLIND', 'amount': 30, 'add_amount': 15, 'player': 'HeuristicPlayer (uuid=mrfdhwthmzmhsjwgobeymq)'}
#       - {'action': 'CALL', 'amount': 30, 'paid': 15, 'player': 'ConsolePlayer (uuid=qdpltubuojkdupqivqnfgc)'}
#       - {'action': 'FOLD', 'player': 'HeuristicPlayer (uuid=mrfdhwthmzmhsjwgobeymq)'}
# ======================================================================
# Enter some key to continue ...
